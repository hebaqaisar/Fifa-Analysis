# %%
#To load the required libraries

import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
import pandas as pd

# %%
fifa = pd.read_csv("C:\\Users\\HIBA QAISAR\\Downloads\\players_15.csv.zip")

# %%
fifa.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2       9014  https://sofifa.com/player/9014/arjen-robben/15...
# 3      41236  https://sofifa.com/player/41236/zlatan-ibrahim...
# 4     167495  https://sofifa.com/player/167495/manuel-neuer/...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   27  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   29  1985-02-05
# 2          A. Robben                         Arjen Robben   30  1984-01-23
# 3     Z. Ibrahimović                   Zlatan Ibrahimović   32  1981-10-03
# 4           M. Neuer                         Manuel Neuer   28  1986-03-27
#
#    height_cm  weight_kg  nationality                 club  ...   lwb   ldm  \
# ...

# %%
fifa.shape
# Out:
# (15465, 104)

# %%
cols = []
for col in fifa:
    print (col)
# Out:
# sofifa_id
# player_url
# short_name
# long_name
# age
# dob
# height_cm
# weight_kg
# nationality
# club
# overall
# potential
# value_eur
# wage_eur
# player_positions
# preferred_foot
# international_reputation
# weak_foot
# skill_moves
# work_rate
# body_type
# real_face
# release_clause_eur
# player_tags
# team_position
# team_jersey_number
# loaned_from
# joined
# contract_valid_until
# nation_position
# nation_jersey_number
# pace
# shooting
# passing
# dribbling
# defending
# physic
# gk_diving
# gk_handling
# gk_kicking
# gk_reflexes
# gk_speed
# gk_positioning
# player_traits
# attacking_crossing
# attacking_finishing
# attacking_heading_accuracy
# attacking_short_passing
# attacking_volleys
# skill_dribbling
# skill_curve
# skill_fk_accuracy
# skill_long_passing
# skill_ball_control
# movement_acceleration
# movement_sprint_speed
# movement_agility
# movement_reactions
# movement_balance
# power_shot_power
# power_jumping
# power_stamina
# power_strength
# power_long_shots
# ...

# %%
fifa['nationality'].value_counts()
# Out:
# nationality
# England          1579
# Spain            1022
# France            875
# Argentina         861
# Italy             778
#                  ...
# Bahrain             1
# Guam                1
# Niger               1
# Oman                1
# Liechtenstein       1
# Name: count, Length: 148, dtype: int64

# %%
england = fifa[fifa['nationality']=='England']

# %%
england.head()
# Out:
#      sofifa_id                                         player_url  \
# 29       54050  https://sofifa.com/player/54050/wayne-rooney/1...
# 68      171833  https://sofifa.com/player/171833/daniel-sturri...
# 78       13732  https://sofifa.com/player/13732/john-terry/15/...
# 123     150724  https://sofifa.com/player/150724/joe-hart/15/1...
# 128      13743  https://sofifa.com/player/13743/steven-gerrard...
#
#        short_name               long_name  age         dob  height_cm  \
# 29      W. Rooney       Wayne Mark Rooney   28  1985-10-24        176
# 68   D. Sturridge  Daniel Andre Sturridge   24  1989-09-01        183
# 78       J. Terry              John Terry   33  1980-12-07        187
# 123       J. Hart                Joe Hart   27  1987-04-19        196
# 128    S. Gerrard         Steven  Gerrard   34  1980-05-30        183
#
#      weight_kg nationality               club  ...   lwb   ldm   cdm   rdm  \
# ...

# %%
fifa['nationality'].value_counts()[:5]
# Out:
# nationality
# England      1579
# Spain        1022
# France        875
# Argentina     861
# Italy         778
# Name: count, dtype: int64

# %%
plt.figure(figsize = (5,7))

plt.bar(fifa['nationality'].value_counts().keys()[:5],fifa['nationality'].value_counts()[:5], color=['blue','green','purple','brown','pink'])
# Out:
# <BarContainer object of 5 artists>

# %%
height = fifa[['short_name', 'height_cm']]

# %%
height.head()
# Out:
#           short_name  height_cm
# 0           L. Messi        169
# 1  Cristiano Ronaldo        185
# 2          A. Robben        180
# 3     Z. Ibrahimović        195
# 4           M. Neuer        193

# %%
height = height.sort_values(by = ['height_cm'], ascending= False)
height.head()
# Out:
#           short_name  height_cm
# 12969     A. Chapman        203
# 1337   C. Pantilimon        203
# 409        L. Traoré        203
# 925       F. Forster        201
# 5474         D. Burn        201

# %%
plt.figure(figsize = (7,7))

plt.bar(height['short_name'][:5],height['height_cm'][:5])
# Out:
# <BarContainer object of 5 artists>

# %%
# Out:
# 12969    203
# 1337     203
# 409      203
# 925      201
# 5474     201
#         ...
# 5840     159
# 3210     159
# 13938    158
# 4102     157
# 13517    155
# Name: height_cm, Length: 15465, dtype: int64

# %%
fifa['nationality']=='Germany'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4         True
#          ...
# 15460    False
# 15461    False
# 15462    False
# 15463    False
# 15464    False
# Name: nationality, Length: 15465, dtype: bool

# %%
germany = fifa[fifa['nationality']=='Germany']
germany.head(5)
# Out:
#     sofifa_id                                         player_url  \
# 4      167495  https://sofifa.com/player/167495/manuel-neuer/...
# 8      121944  https://sofifa.com/player/121944/bastian-schwe...
# 13     121939  https://sofifa.com/player/121939/philipp-lahm/...
# 21     178603  https://sofifa.com/player/178603/mats-hummels/...
# 23     188350  https://sofifa.com/player/188350/marco-reus/15...
#
#            short_name               long_name  age         dob  height_cm  \
# 4            M. Neuer            Manuel Neuer   28  1986-03-27        193
# 8   B. Schweinsteiger  Bastian Schweinsteiger   29  1984-08-01        183
# 13            P. Lahm            Philipp Lahm   30  1983-11-11        170
# 21         M. Hummels           Mats  Hummels   25  1988-12-16        192
# 23            M. Reus              Marco Reus   25  1989-05-31        181
#
#     weight_kg nationality               club  ...   lwb   ldm   cdm   rdm  \
# ...

# %%
height_cm = germany.sort_values(by = 'height_cm', ascending = False)

height_cm.head(5)
# Out:
#       sofifa_id                                         player_url  \
# 8877     169223  https://sofifa.com/player/169223/thorsten-stuc...
# 8814     150389  https://sofifa.com/player/150389/benedikt-pliq...
# 2029     199833  https://sofifa.com/player/199833/lars-unnersta...
# 7642     200212  https://sofifa.com/player/200212/michael-esser...
# 79        53612  https://sofifa.com/player/53612/per-mertesacke...
#
#           short_name           long_name  age         dob  height_cm  \
# 8877    T. Stuckmann  Thorsten Stuckmann   33  1981-03-17        199
# 8814     B. Pliquett   Benedikt Pliquett   29  1984-12-20        199
# 2029   L. Unnerstall     Lars Unnerstall   23  1990-07-20        198
# 7642        M. Esser       Michael Esser   26  1987-11-22        198
# 79    P. Mertesacker     Per Mertesacker   29  1984-09-29        198
#
#       weight_kg nationality                club  ...   lwb   ldm   cdm   rdm  \
# ...

# %%
weight_kg = germany.sort_values(by = 'weight_kg', ascending = False)

weight_kg.head(5)
# Out:
#        sofifa_id                                         player_url  \
# 1745       53012  https://sofifa.com/player/53012/tim-wiese/15/1...
# 2029      199833  https://sofifa.com/player/199833/lars-unnersta...
# 8877      169223  https://sofifa.com/player/169223/thorsten-stuc...
# 7642      200212  https://sofifa.com/player/200212/michael-esser...
# 13726     224251  https://sofifa.com/player/224251/robin-zentner...
#
#           short_name           long_name  age         dob  height_cm  \
# 1745        T. Wiese           Tim Wiese   32  1981-12-17        193
# 2029   L. Unnerstall     Lars Unnerstall   23  1990-07-20        198
# 8877    T. Stuckmann  Thorsten Stuckmann   33  1981-03-17        199
# 7642        M. Esser       Michael Esser   26  1987-11-22        198
# 13726     R. Zentner       Robin Zentner   19  1994-10-28        194
#
#        weight_kg nationality                 club  ...  lwb  ldm  cdm  rdm  \
# ...

# %%
highest = germany[['short_name', 'height_cm']].sort_values(by = 'height_cm', ascending = False)

highest.head()
# Out:
#           short_name  height_cm
# 8877    T. Stuckmann        199
# 8814     B. Pliquett        199
# 2029   L. Unnerstall        198
# 7642        M. Esser        198
# 79    P. Mertesacker        198

# %%
players_shooting = fifa[['short_name','shooting']]
players_shooting.head()
# Out:
#           short_name  shooting
# 0           L. Messi      89.0
# 1  Cristiano Ronaldo      93.0
# 2          A. Robben      86.0
# 3     Z. Ibrahimović      91.0
# 4           M. Neuer       NaN

# %%
players_shooting.sort_values(by = 'shooting', ascending = False).head()
# Out:
#            short_name  shooting
# 1   Cristiano Ronaldo      93.0
# 3      Z. Ibrahimović      91.0
# 7       R. van Persie      90.0
# 0            L. Messi      89.0
# 29          W. Rooney      87.0

# %%
defending = fifa[['short_name','nationality','defending','club']]
defending.head()
# Out:
#           short_name  nationality  defending                 club
# 0           L. Messi    Argentina       27.0         FC Barcelona
# 1  Cristiano Ronaldo     Portugal       32.0          Real Madrid
# 2          A. Robben  Netherlands       32.0    FC Bayern München
# 3     Z. Ibrahimović       Sweden       34.0  Paris Saint-Germain
# 4           M. Neuer      Germany        NaN    FC Bayern München

# %%
defending.sort_values(by = 'defending', ascending = False).head()
# Out:
#       short_name nationality  defending                 club
# 15  Thiago Silva      Brazil       90.0  Paris Saint-Germain
# 21    M. Hummels     Germany       88.0    Borussia Dortmund
# 49    M. Benatia     Morocco       88.0    FC Bayern München
# 13       P. Lahm     Germany       87.0    FC Bayern München
# 57  G. Chiellini       Italy       87.0             Juventus

# %%
real_madrid = fifa[fifa['club'] == 'Real Madrid']
real_madrid.head()
# Out:
#     sofifa_id                                         player_url  \
# 1       20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 11     173731  https://sofifa.com/player/173731/gareth-bale/1...
# 14     155862  https://sofifa.com/player/155862/sergio-ramos-...
# 17     177003  https://sofifa.com/player/177003/luka-modric/1...
# 18     198710  https://sofifa.com/player/198710/james-rodrigu...
#
#            short_name                            long_name  age         dob  \
# 1   Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   29  1985-02-05
# 11            G. Bale                    Gareth Frank Bale   24  1989-07-16
# 14       Sergio Ramos                  Sergio Ramos García   28  1986-03-30
# 17          L. Modrić                          Luka Modrić   28  1985-09-09
# 18       J. Rodríguez          James David Rodríguez Rubio   22  1991-07-12
#
#     height_cm  weight_kg nationality         club  ...   lwb   ldm   cdm  \
# ...

# %%
real_height = real_madrid[['short_name','height_cm']].sort_values(by = 'height_cm', ascending = False)
real_height.head()
# Out:
#         short_name  height_cm
# 7674  E. Markkanen        197
# 152      R. Varane        191
# 8139   Rubén Yáñez        190
# 50      S. Khedira        189
# 81            Pepe        188

# %%
real_madrid[['short_name','weight_kg']].sort_values(by = 'weight_kg', ascending = False).head(5)
# Out:
#         short_name  weight_kg
# 7674  E. Markkanen         97
# 50      S. Khedira         85
# 53        Casillas         84
# 9350       Pacheco         82
# 8139   Rubén Yáñez         81

# %%
real_madrid['nationality'].value_counts()
# Out:
# nationality
# Spain         17
# Portugal       3
# Germany        2
# France         2
# Brazil         2
# Wales          1
# Croatia        1
# Colombia       1
# Mexico         1
# Costa Rica     1
# Finland        1
# Uruguay        1
# Name: count, dtype: int64
